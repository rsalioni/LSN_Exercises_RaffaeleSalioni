# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("output1.01.txt", usecols=(0,1,2), delimiter=', ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("output1.02.txt", usecols=(0,1,2), delimiter=', ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()

# %%
n_bins = 30
x = np.loadtxt("output1.03.txt")
n, bins, patches = plt.hist(x, n_bins, range=(55,145))

plt.xlabel('Chisquare')
plt.ylabel('Probability')
plt.title('Histogram of Chi')
plt.grid(True)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("output1.01test.txt", usecols=(0,1,2), delimiter=', ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("output1.02test.txt", usecols=(0,1,2), delimiter=', ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()
