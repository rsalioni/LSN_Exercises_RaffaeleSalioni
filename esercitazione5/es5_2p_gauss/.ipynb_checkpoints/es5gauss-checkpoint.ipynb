# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("rmedia2p_gauss.txt", usecols=(0,1,2), delimiter=', ', unpack='true')
plt.errorbar(x,f - 5.0 ,yerr=error)
plt.xlabel('#blocchi')
plt.ylabel('<r>- 5.0')
plt.title("valore medio r - autostato 2p")
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

X, Y, Z = np.loadtxt("pos2p_gauss.txt", usecols=(0,1,2), delimiter=', ', unpack='true')

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 30)
plt.title("autostato 2p")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


temp = np.loadtxt('r_eq2p_gauss.txt')
x = np.arange(temp.size)

plt.figure(figsize=(10,7))

plt.plot(x,temp)
plt.title("titolo")
plt.grid(True)
