# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.3 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=50, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 20/20 [==============================] - 1s 12ms/step - loss: 1.0826 - mse: 1.0826 - val_loss: 0.8305 - val_mse: 0.8305
# Epoch 2/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6277 - mse: 0.6277 - val_loss: 0.5222 - val_mse: 0.5222
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4011 - mse: 0.4011 - val_loss: 0.3611 - val_mse: 0.3611
# Epoch 4/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2828 - mse: 0.2828 - val_loss: 0.2711 - val_mse: 0.2711
# Epoch 5/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2166 - mse: 0.2166 - val_loss: 0.2161 - val_mse: 0.2161
# Epoch 6/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1767 - mse: 0.1767 - val_loss: 0.1802 - val_mse: 0.1802
# Epoch 7/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1511 - mse: 0.1511 - val_loss: 0.1552 - val_mse: 0.1552
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1337 - mse: 0.1337 - val_loss: 0.1371 - val_mse: 0.1371
# Epoch 9/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1214 - mse: 0.1214 - val_loss: 0.1236 - val_mse: 0.1236
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1125 - mse: 0.1125 - val_loss: 0.1132 - val_mse: 0.1132
# Epoch 11/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1059 - mse: 0.1059 - val_loss: 0.1053 - val_mse: 0.1053
# Epoch 12/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1010 - mse: 0.1010 - val_loss: 0.0990 - val_mse: 0.0990
# Epoch 13/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0973 - mse: 0.0973 - val_loss: 0.0941 - val_mse: 0.0941
# Epoch 14/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0944 - mse: 0.0944 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 15/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0922 - mse: 0.0922 - val_loss: 0.0872 - val_mse: 0.0872
# Epoch 16/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0848 - val_mse: 0.0848
# Epoch 17/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0894 - mse: 0.0894 - val_loss: 0.0828 - val_mse: 0.0828
# Epoch 18/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0884 - mse: 0.0884 - val_loss: 0.0812 - val_mse: 0.0812
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0877 - mse: 0.0877 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 20/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0871 - mse: 0.0871 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 21/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0867 - mse: 0.0867 - val_loss: 0.0781 - val_mse: 0.0781
# Epoch 22/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0864 - mse: 0.0864 - val_loss: 0.0774 - val_mse: 0.0774
# Epoch 23/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0861 - mse: 0.0861 - val_loss: 0.0769 - val_mse: 0.0769
# Epoch 24/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0859 - mse: 0.0859 - val_loss: 0.0764 - val_mse: 0.0764
# Epoch 25/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0858 - mse: 0.0858 - val_loss: 0.0760 - val_mse: 0.0760
# Epoch 26/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0857 - mse: 0.0857 - val_loss: 0.0757 - val_mse: 0.0757
# Epoch 27/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0856 - mse: 0.0856 - val_loss: 0.0754 - val_mse: 0.0754
# Epoch 28/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0752 - val_mse: 0.0752
# Epoch 29/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0750 - val_mse: 0.0750
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0749 - val_mse: 0.0749

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.9846938]], dtype=float32), array([1.0045913], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0749 - mse: 0.0749
#
# Test loss: 0.07485204935073853
# Test accuracy: 0.07485204935073853

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1745e-04 - mse: 1.1745e-04
#
# Test loss: 0.00011744949733838439
# Test accuracy: 0.00011744949733838439

# %%
# look into training history
# Plot training & validation loss values
plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
